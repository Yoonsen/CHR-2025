# %%
import pandas as pd

# %%
data = pd.read_excel("../data/merged_test_set.xlsx")

# %%
data
# Out:
#       id lang                                           sentence  \
# 0     1a   no             Hvilken artikkel kastet du uten å lese
# 1     1b   no         Hvilken artikkel kastet du uten å lese den
# 2     1c   no         Hvilken artikkel kastet du den uten å lese
# 3     1d   no     Hvilken artikkel kastet du den uten å lese den
# 4     1a   en   Which article did you throw away without reading
# ..   ...  ...                                                ...
# 57  lbe2   no             Hvem sa hun at de malte et portrett av
# 58  lbe3   en     Who do you believe pictures of will be on sale
# 59  lbe4   en   Who did she say portraits of hung in the gallery
# 60  lbe3   no  Hvem tror du at bilder av vil bli lagt ut for ...
# 61  lbe4   no      Hvem sa hun at portretter av hang i galleriet
#
#                  condition  grammatical          source
# 0                both open         True  parasitic gaps
# 1        parasitic plugged         True  parasitic gaps
# ...
