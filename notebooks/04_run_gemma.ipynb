# %%
import os
from huggingface_hub import login
accesskey = os.getenv("HF_ACCESSKEY") 
login(accesskey)

# %%
import importlib
import run_tests as rt
import pandas as pd
importlib.reload(rt)
# Out:
# <module 'run_tests' from '/mnt/disk1/Github/CHR-2025/notebooks/run_tests.py'>

# %%
# === PARAMETRE ===
model_name = "google/gemma-7b-it" # eller f.eks. "google/gemma-7b-it"
output_file = "../results/scores_gemma.csv"
trust = True

importlib.reload(rt)

file_path = "../data/merged_test_set.xlsx"
df = pd.read_excel(file_path)

rt.run_tests(model_name, output_file, trust=trust, N=len(df), df=df)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ...
