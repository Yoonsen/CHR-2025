# %%
import json
import pandas as pd
from tqdm import tqdm
import subprocess
import openai

# === KONFIG ===
PROJECT_ID = "norwegian-language-bank"
LOCATION = "us-central1"
MODEL_ID = "meta/llama3-405b-instruct-maas"

# === HENT TOKEN ===
def get_access_token():
    result = subprocess.run(
        ["gcloud", "auth", "print-access-token"],
        stdout=subprocess.PIPE,
        text=True,
        check=True
    )
    return result.stdout.strip()

# === INITIALISER KLIENT ===
def get_client(token):
    return openai.OpenAI(
        base_url=f"https://{LOCATION}-aiplatform.googleapis.com/v1beta1/projects/{PROJECT_ID}/locations/{LOCATION}/endpoints/openapi/chat/completions?",
        api_key=token
    )

# === PROMPT ===
PROMPT = """You are a linguist evaluating sentences in {lang}.
Each sentence should be rated solely for its grammatical acceptability.
Use the following 5-point scale:

1 – completely ungrammatical
2 – mostly ungrammatical
3 – marginal
4 – mostly grammatical
5 – fully grammatical

Return a JSON object with the format:
{{"score": <number>, "explanation": "<short explanation>"}}

Only provide one evaluation per sentence.

Here is the sentence:
{sentence}
"""

# === KJØRING ===
def process_chunk(chunk_text, lang):
    token = get_access_token()
    client = get_client(token)

    response = client.chat.completions.create(
        model=MODEL_ID,
        max_tokens=3000,
        messages=[{
            "role": "user",
            "content": PROMPT.format(lang=lang, sentence=chunk_text)
        }]
    )
    return response

# %%
import time

# %%
file_path = "../data/data_for_processing.xlsx"
output_file = "../results/llama_nb_friday.csv"
df = pd.read_excel(file_path)
N=len(df)

# %%
import json

# %%
records=[]
for i, row in df.iloc[:N].iterrows():
    sent = row["sentence"]
    try:
        lang = "Norwegian" if "-n-" in row["code"] else "English"
        raw_output = process_chunk(sent, lang)
        try:
            parsed = json.loads(raw_output.choices[0].message.content)
            score = parsed["score"]
        
            records.append({
                "example_id": row["Unnamed: 0"],
                "sentence": sent,
                "code": row['code'],
                "keyword":row['keyword'],
                "lang": lang,
                'score':score,
                "raw_output": parsed['explanation']
        
            })
        except:
            print(row["Unnamed: 0"], raw_output.choices[0].message.content)
        time.sleep(0.5)
    except:
        pass

out_df = pd.DataFrame(records)
out_df.to_csv(output_file, index=False)
print("Done.")
# Out:
# Done.

# %%
out_df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_aa514">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa514_level0_col0" class="col_heading level0 col0" >example_id</th>
#       <th id="T_aa514_level0_col1" class="col_heading level0 col1" >sentence</th>
#       <th id="T_aa514_level0_col2" class="col_heading level0 col2" >code</th>
#       <th id="T_aa514_level0_col3" class="col_heading level0 col3" >keyword</th>
#       <th id="T_aa514_level0_col4" class="col_heading level0 col4" >lang</th>
#       <th id="T_aa514_level0_col5" class="col_heading level0 col5" >score</th>
#       <th id="T_aa514_level0_col6" class="col_heading level0 col6" >raw_output</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa514_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aa514_row0_col0" class="data row0 col0" >0</td>
# ...
